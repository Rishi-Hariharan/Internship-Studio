# %%
#importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # New section

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-02d490c7-b500-4824-b599-628f14cec3ac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-02d490c7-b500-4824-b599-628f14cec3ac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving datasets_48024_87370_Bank_Personal_Loan_Modelling.csv to datasets_48024_87370_Bank_Personal_Loan_Modelling.csv

# %%
import io
dataset = pd.read_csv(io.BytesIO(uploaded ['datasets_48024_87370_Bank_Personal_Loan_Modelling.csv']))

# %%
#To display top 5 rows
dataset.head(5)

# %%
#To display bottom 5 rows
dataset.tail(5)

# %%
#To display datatype of each column and non-null rows for each column
dataset.info()

# %%
#To display summary stats
dataset.describe()

# %%
#To display no. of null values in each column
dataset.isnull().sum()

# %%
#Checking Correlation
experience = dataset ['Experience']
age = dataset ['Age']
correlation = experience.corr(age)
correlation

# %%
#Dropping Columns
dataset = dataset.drop(['ID', 'Experience'], axis = 1)
dataset.head(5)

# %%
#No. of unique in each column
dataset.nunique()

# %%
#Drop Nominal variable Zip Code
dataset.drop('ZIP Code', axis = 1)

# %%
#No. of people with zero Mortgage
(dataset.Mortgage == 0).sum()

# %%
 
#No. of people with zero credit card spending per month
(dataset.CCAvg == 0).sum()

# %%
#Value counts for categorical columns
dataset.Family.value_counts()

# %%
dataset.Education.value_counts()

# %%
dataset['Securities Account'].value_counts()

# %%
 dataset['CD Account'].value_counts()

# %%
 dataset['CreditCard'].value_counts()

# %%
 dataset.Online.value_counts()

# %%
#Univariate Analysis
#Age distribution plot
sns.distplot(dataset.Age);

# %%
#Income distribution plot
sns.distplot(dataset.Income);

# %%
 #Credit card Avg distribution plot
sns.distplot(dataset.CCAvg);

# %%
 #Mortgage distribution plot
sns.distplot(dataset.Mortgage);

# %%
sns.countplot(dataset.Family);

# %%
 sns.countplot(dataset.Education);

# %%
#Multivariate Analysis

# %%
sns.boxplot(x='Education', y='Income', hue='Personal Loan', data=dataset);

# %%
sns.countplot(x='Securities Account', data=dataset, hue='Personal Loan');

# %%
#CCAvg and Income seems to be correlated
fig,ax = plt.subplots(figsize = (15,10))
sns.heatmap(dataset.corr(), cmap = 'plasma', annot = True);

# %%
sns.pairplot(dataset)

# %%
data_X = dataset.loc[:, dataset.columns != 'Personal Loan']
data_Y = dataset['Personal Loan']

# %%
#Transformations of feature variables
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer(method = 'yeo-johnson', standardize = False)
pt.fit(data_X['Income'].values.reshape(-1,1))
temp = pt.transform(data_X['Income'].values.reshape(-1,1))
sns.distplot(temp);

# %%
data_X['Mortgage_Int']=pd.cut(data_X['Mortgage'], bins = [0,100,200,300,400,500,600,700], labels = [0,1,2,3,4,5,6], include_lowest = True)
data_X.drop('Mortgage', axis = 1, inplace = True)

# %%
data_X.head()

# %%
#Univariate Analysis
tempDF = pd.DataFrame(dataset['Personal Loan'].value_counts()).reset_index()
tempDF.columns = ['Labels', 'Personal Loan']
fig1, ax1 = plt.subplots(figsize = (10,8))
explode = (0,0.15)
ax1.pie(tempDF['Personal Loan'], explode = explode, autopct = '%1.1f%%', shadow = True, startangle = 70)
ax1.axis('equal')
plt.title('Personal Loan Percentage')
plt.show()

# %%
#Splitting of Data
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(data_X, data_Y, test_size=0.25, stratify=data_Y, random_state = 0)

# %%
print('Shape of X_train is:', X_train.shape)
print('Shape of X_test is:', X_test.shape)
print('Shape of Y_train is:', Y_train.shape)
print('Shape of Y_test is:', Y_test.shape)

# %%
#Logistic Regression

from sklearn.linear_model import LogisticRegression
log = LogisticRegression ()

# %%
log.fit(X_train, Y_train)

# %%
log.score(X_train, Y_train)

# %%
#Predicting test dataset
 
pred11 = log.predict(X_test)
pred22 = log.predict(X_train)

# %%
#importing library for classification performance metrics
 
from sklearn import metrics

# %%
#test Confusion Matrix
metrics.confusion_matrix(Y_test, pred11)

# %%
#train Confusion Matrix
metrics.confusion_matrix(Y_train, pred22)

# %%
#test accuracy score
metrics.accuracy_score(Y_test, pred11)

# %%
#train accuracy score
metrics.accuracy_score(Y_train, pred22)

# %%
#Decision Tree
 
from sklearn.tree import DecisionTreeClassifier
clf=DecisionTreeClassifier()

# %%
clf.fit(X_train, Y_train)

# %%
clf.score(X_train, Y_train)

# %%
pred1 = clf.predict(X_test)
pred2 = clf.predict(X_train)

# %%
#test Confusion Matrix
metrics.confusion_matrix(Y_test, pred1)

# %%
 #train Confusion Matrix
metrics.confusion_matrix(Y_train, pred2)

# %%
 #test accuracy score
metrics.accuracy_score(Y_test, pred1)

# %%
 #train accuracy score
metrics.accuracy_score(Y_train, pred2)

# %%
#Random Forest
 
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
clf.fit(X_train, Y_train)

# %%
Y_pred = clf.predict(X_test)

# %%
print('Accuracy score for test data', metrics.accuracy_score(Y_test, Y_pred))

# %%
print('Accuracy score for train data', metrics.accuracy_score(Y_train, model.predict(X_train)))

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(Y_test, Y_pred))

# %%
#Naive Bayes
 
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, Y_train)

# %%
Y_pred = model.predict(X_test)

# %%
 print('Accuracy score for test data', metrics.accuracy_score(Y_test, Y_pred))

# %%
print('Accuracy score for train data', metrics.accuracy_score(Y_train, model.predict(X_train)))

# %%
 from sklearn.metrics import confusion_matrix
print(confusion_matrix(Y_test, Y_pred))

# %%
##CONCLUSION REPORT
 
#   The main aim of the project was to predict
#   whether a person will take a personal loan 
#   or not through model. The summary of the 
#   above carried out processes is as follows.
 
#   1) First imported libraries and our data
 
#   2) Checked correlation and dropped highly
#      correlated columns(age, experience) 
#      along with unwanted columns(ID, ZIP Code)
  
#   3) Applied transformations to skewed data
  
#   4) Finally, used several models(Decision tree,
#      Random forest, Naive Bayes) to make predictions
#      and checked accuracy, displayed Confusion Matrix
#      to know how good the model works.
